# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Charger les données depuis un fichier Excel
data = pd.read_excel("C:/Users/stagiaireprodaad/OneDrive - SAINTE LUCIE/Bureau/ML/Journalier/L48.xlsx")
data = data.fillna(0)

while True:

    # Demande à l'utilisateur d'entrer le nombre de paramètres d'entrée
    features_number = int(input("Entrez le nombre de paramètres d'entrée : "))

    # Crée une liste vide pour stocker les paramètres
    features = []

    # Demande à l'utilisateur d'entrer les noms des paramètres
    for i in range(features_number):
        feature = input("Entrez le nom du paramètre d'entrée {} : ".format(i+1))
        features.append(feature)

    # Affiche les paramètres entrés par l'utilisateur
    print("Les paramètres d'entrée sont :", features)



    # Demande à l'utilisateur d'entrer le nombre de paramètres cibles
    targets_number = int(input("Entrez le nombre de paramètres cibles : "))

    # Crée une liste vide pour stocker les paramètres
    targets = []

    # Demande à l'utilisateur d'entrer les noms des paramètres
    for i in range(targets_number):
        target = input("Entrez le nom du paramètre cible {} : ".format(i+1))
        targets.append(target)


    # Affiche les paramètres entrés par l'utilisateur
    print("Les paramètres cibles sont :", targets)

    # Séparer les caractéristiques
    features_data = data[features]
    targets_data = data[targets]

    # Normaliser les caractéristiques
    scaler = MinMaxScaler()
    features_scaled = scaler.fit_transform(features_data)

    # Créer le modèle de Deep Learning
    model = Sequential()
    model.add(Dense(64, input_dim=features_number, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(targets_number, activation='linear'))

    # Compiler le modèle
    model.compile(loss='mean_squared_error', optimizer='adam')

    # Entraîner le modèle
    model.fit(features_scaled, targets_data, epochs=100, batch_size=32, verbose=1)

    while True:
        
        # Obtenir de nouvelles données d'entrée de l'utilisateur
        valeurs = []
        for i in range(features_number):
            valeur = float(input("Entrez la valeur numérique pour le paramètre d'entrée {} : ".format(features[i])))
            valeurs.append(valeur)
            print(valeur)

        new = {}
        for i in range(features_number):
            cle = f"{features[i]}"
            v = [valeurs[i]]
            new[cle] = v

        new_data = pd.DataFrame(new)

        new_data_scaled = scaler.transform(new_data)

        # Prédire les valeurs
        predictions = model.predict(new_data_scaled)

        rounded_predictions = np.round(predictions.flatten(), 2)
        print("Prédictions :")
        for i in range (targets_number):
            print(targets[i], "=", rounded_predictions[i])

        # Demander à l'utilisateur s'il souhaite effectuer une autre prédiction
        choice = input("Souhaitez-vous effectuer une autre prédiction ? (Oui/Non): ")
        if choice.lower() != "oui":
            break

    # Demander à l'utilisateur s'il souhaite changer de paramètres
    choice = input("Souhaitez-vous définir de nouveaux paramètres ? (Oui/Non): ")
    if choice.lower() != "oui":
        break
# Out:
# Entrez le nombre de paramètres d'entrée : 6
# Entrez le nom du paramètre d'entrée 1 : QTE FAB
# Entrez le nom du paramètre d'entrée 2 : TO
# Entrez le nom du paramètre d'entrée 3 : MO
# Entrez le nom du paramètre d'entrée 4 : AMP01
# Entrez le nom du paramètre d'entrée 5 : AMP02
# Entrez le nom du paramètre d'entrée 6 : AM001
# Les paramètres d'entrée sont : ['QTE FAB', 'TO', 'MO', 'AMP01', 'AMP02', 'AM001']
# Entrez le nombre de paramètres cibles : 4
# Entrez le nom du paramètre cible 1 : %TRS
# Entrez le nom du paramètre cible 2 : %REGLAGE
# Entrez le nom du paramètre cible 3 : %NETTOYAGE
# Entrez le nom du paramètre cible 4 : %PANNE
# Les paramètres cibles sont : ['%TRS', '%REGLAGE', '%NETTOYAGE', '%PANNE']
# Epoch 1/100
# 3/3 [==============================] - 1s 6ms/step - loss: 0.4261
# Epoch 2/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3661
# Epoch 3/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3160
# Epoch 4/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2698
# Epoch 5/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2315
# Epoch 6/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1932
# Epoch 7/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1607
# Epoch 8/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1350
# Epoch 9/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1137
# Epoch 10/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0994
# Epoch 11/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0845
# Epoch 12/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0723
# Epoch 13/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0643
# Epoch 14/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0572
# Epoch 15/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0502
# Epoch 16/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0453
# Epoch 17/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0410
# Epoch 18/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0383
# Epoch 19/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0352
# Epoch 20/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0334
# Epoch 21/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0310
# Epoch 22/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0289
# Epoch 23/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0270
# Epoch 24/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0245
# Epoch 25/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0229
# Epoch 26/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0219
# Epoch 27/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0202
# Epoch 28/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0185
# Epoch 29/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0171
# Epoch 30/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0162
# Epoch 31/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0152
# Epoch 32/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0139
# Epoch 33/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0132
# Epoch 34/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0129
# Epoch 35/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0120
# Epoch 36/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0116
# Epoch 37/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0109
# Epoch 38/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0110
# Epoch 39/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0104
# Epoch 40/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0104
# Epoch 41/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0098
# Epoch 42/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0098
# Epoch 43/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0095
# Epoch 44/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0094
# Epoch 45/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0091
# Epoch 46/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0091
# Epoch 47/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0090
# Epoch 48/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0087
# Epoch 49/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0085
# Epoch 50/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0086
# Epoch 51/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0083
# Epoch 52/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0085
# Epoch 53/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0083
# Epoch 54/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0080
# Epoch 55/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0079
# Epoch 56/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0079
# Epoch 57/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0080
# Epoch 58/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0078
# Epoch 59/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0077
# Epoch 60/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0075
# Epoch 61/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0074
# Epoch 62/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0074
# Epoch 63/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0074
# Epoch 64/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0074
# Epoch 65/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0072
# Epoch 66/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0071
# Epoch 67/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0070
# Epoch 68/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0070
# Epoch 69/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0069
# Epoch 70/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0068
# Epoch 71/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0070
# Epoch 72/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0066
# Epoch 73/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0067
# Epoch 74/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0065
# Epoch 75/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0069
# Epoch 76/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0063
# Epoch 77/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0064
# Epoch 78/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0062
# Epoch 79/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0063
# Epoch 80/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0062
# Epoch 81/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0062
# Epoch 82/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0061
# Epoch 83/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0061
# Epoch 84/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0062
# Epoch 85/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0058
# Epoch 86/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0059
# Epoch 87/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0058
# Epoch 88/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0057
# Epoch 89/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0055
# Epoch 90/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0056
# Epoch 91/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0054
# Epoch 92/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0057
# Epoch 93/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0058
# Epoch 94/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0054
# Epoch 95/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0056
# Epoch 96/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0055
# Epoch 97/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0054
# Epoch 98/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0053
# Epoch 99/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0051
# Epoch 100/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0050
# Entrez la valeur numérique pour le paramètre d'entrée QTE FAB : 13824
# 13824.0
# Entrez la valeur numérique pour le paramètre d'entrée TO : 7.5
# 7.5
# Entrez la valeur numérique pour le paramètre d'entrée MO : 21
# 21.0
# Entrez la valeur numérique pour le paramètre d'entrée AMP01 : 0.2
# 0.2
# Entrez la valeur numérique pour le paramètre d'entrée AMP02 : 0.2
# 0.2
# Entrez la valeur numérique pour le paramètre d'entrée AM001 : 0.8
# 0.8
# 1/1 [==============================] - 0s 106ms/step
# Prédictions :
# %TRS = 1.45
# %REGLAGE = 0.06
# %NETTOYAGE = 0.05
# %PANNE = 0.05
# Souhaitez-vous effectuer une autre prédiction ? (Oui/Non): NON
# Souhaitez-vous définir de nouveaux paramètres ? (Oui/Non): NON
